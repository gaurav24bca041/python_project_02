# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\naveen kumar\OneDrive\Desktop\python\jupiter notebook\Indian_Patients.csv")

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.head
# Out:
# <bound method NDFrame.head of      Token Number          Name          State  Phone Number   Department  \
# 0               1     Patient_1        Gujarat    7971282522    Neurology
# 1               2     Patient_2  Uttar Pradesh    8745163911   Cardiology
# 2               3     Patient_3    Maharashtra    7483035696  Dermatology
# 3               4     Patient_4          Bihar    9640701228   Pediatrics
# 4               5     Patient_5          Bihar    7880886742   Pediatrics
# ..            ...           ...            ...           ...          ...
# 995           996   Patient_996    West Bengal    7553735553   Pediatrics
# 996           997   Patient_997         Punjab    8104204964   Psychiatry
# 997           998   Patient_998         Punjab    6378639047   Gynecology
# 998           999   Patient_999        Gujarat    9171247831  Orthopedics
# 999          1000  Patient_1000    Maharashtra    7082966559  Orthopedics
#
#      Rating  Gender  Age Age Group
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Token Number  1000 non-null   int64
#  1   Name          1000 non-null   object
#  2   State         1000 non-null   object
#  3   Phone Number  1000 non-null   int64
#  4   Department    1000 non-null   object
#  5   Rating        1000 non-null   float64
#  6   Gender        1000 non-null   object
#  7   Age           1000 non-null   int64
#  8   Age Group     1000 non-null   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 70.4+ KB

# %%
pd.isnull(df)
# Out:
#      Token Number   Name  State  Phone Number  Department  Rating  Gender  \
# 0           False  False  False         False       False   False   False
# 1           False  False  False         False       False   False   False
# 2           False  False  False         False       False   False   False
# 3           False  False  False         False       False   False   False
# 4           False  False  False         False       False   False   False
# ..            ...    ...    ...           ...         ...     ...     ...
# 995         False  False  False         False       False   False   False
# 996         False  False  False         False       False   False   False
# 997         False  False  False         False       False   False   False
# 998         False  False  False         False       False   False   False
# 999         False  False  False         False       False   False   False
#
#        Age  Age Group
# 0    False      False
# 1    False      False
# ...

# %%
pd.isnull(df).sum()
# Out:
# Token Number    0
# Name            0
# State           0
# Phone Number    0
# Department      0
# Rating          0
# Gender          0
# Age             0
# Age Group       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Token Number', 'Name', 'State', 'Phone Number', 'Department', 'Rating',
#        'Gender', 'Age', 'Age Group'],
#       dtype='object')

# %%
sns.countplot(x='Gender',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
ax = sns.countplot(x='Gender',data=df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df.groupby(['Gender'],as_index=False)['Department'].sum().sort_values(by='Department',ascending=False)
# Out:
#    Gender                                         Department
# 0  Female  NeurologyPediatricsCardiologyGeneral MedicineP...
# 2   Other  DermatologyPsychiatryPsychiatryPsychiatryENTOr...
# 1    Male  CardiologyPediatricsPediatricsENTPsychiatryOph...

# %%
sns.countplot(data=df,x='Age Group',hue='Gender')
# Out:
# <Axes: xlabel='Age Group', ylabel='count'>

# %%
ax = sns.countplot(data=df,x='Age Group',hue='Gender')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
gg = sns.countplot(data=df,x='Department',hue='Age Group')
sns.set(rc={'figure.figsize':(15,7)})
for bars in gg.containers:
    gg.bar_label(bars)

# %%
d_state= df.groupby(['State'],as_index=False)['Department'].sum().sort_values(by='Department',ascending=False)
sns.set(rc={'figure.figsize':(15,15)})
sns.barplot(data=d_state,x='State',y='Department')
# Out:
# <Axes: xlabel='State', ylabel='Department'>

# %%
ax = sns.countplot(data=df,x='State',hue='Department')
sns.set(rc={'figure.figsize':(20,7)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax=sns.countplot(data=df,x='Age Group',hue='Rating')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax= sns.countplot(data=df,x='State')
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# Conclusion:
#
#  1. Seniors are more visiting cardiac, orthopedic and pychiatry department.
#  2. Teen are more visited neuro and dermatology department
#  3. child are more visiting at ENT and pideatric
#  4. adult more visted at pychiatry and orthopadic department
#
# - From bihar more visited cardia department.
# - From gujrat more visted in ortho department
# Most people are come from punjab to visit opthamology department
